# %%
import numpy as np
from IPython.display import clear_output

from tictactoe import TicTacToe

# %%
def hashBoard(board):
    result = 0
    for i in range(9):
        if board[i] == -1:
            result += 2 * 3 ** i
        else:
            result += board[i] * 3 ** i
    return int(result)

def choose_action(board, mode='best', epsilon=0.2):
    global q_table
    q_action = q_table[hashBoard(board)]
    ac_idx = np.argwhere(board == 0).flatten()
    q_action = q_action[board == 0]
    if mode == 'best':
        best_idx = np.argmax(q_action)
        return ac_idx[best_idx]
    if mode == 'advn':
        if np.random.random() > epsilon:
            best_idx = np.argmax(q_action)
            return ac_idx[best_idx]
        else:
            n_action = n_table[hashBoard(board)][board == 0]
            min_idx = np.argmin(n_action)
            return ac_idx[min_idx]
    if mode == 'rand':
        if np.random.random() > epsilon:
            best_idx = np.argmax(q_action)
            return ac_idx[best_idx]
        else:
            rand_idx = np.random.choice(ac_idx.shape[0])
            return ac_idx[rand_idx]
    else:
        raise Exception('没有这种方法。')
    
def updateQTable(board, turn, action, win, done, _board, lr=0.01):
    global q_table
    b_num = hashBoard(board * turn)
    n_table[b_num, action] += 1

    _b_num = hashBoard(_board * -turn)
    if done:
        q_table[_b_num, :] = win * -turn
        q_target = win * -turn * gamma
    else:
        q_target = q_table[_b_num, _board == 0].max() * gamma
    q_table[b_num, action] += (-q_target - q_table[b_num, action]) * lr

# %%
gamma = 0.9
lr = 0.01
epsilon = 1
epsilon_delay = 0.99999
epsilon_min = 0.2

ttt = TicTacToe()
q_table = np.zeros([3 ** 9, 9])
n_table = np.zeros([3 ** 9, 9])

# %%
q_table = np.load('model/tictactoe_qlearning.npz')['q_table']

# %%
total_round = 50000
win_round = 0
draw_round = 0
for cur_round in range(total_round):
    board, turn, win, done = ttt.reset(np.random.choice([1, -1], 1)[0])
    while not done:
        if turn == 1:
            action = choose_action(board * turn, mode='advn', epsilon=epsilon)
        elif turn == -1:
            action = choose_action(board * turn, mode='best')
        _board, _turn, win, done = ttt.step(action)
        
        updateQTable(board, turn, action, win, done, _board, lr=lr)
        
        board = _board
        turn = _turn
    
    epsilon = max(epsilon * epsilon_delay, epsilon_min)
    
    if win == 1:
        win_round += 1
    elif win == 0:
        draw_round += 1
    if (cur_round + 1) % 100 == 0:
        print('已完成%d轮，玩家一胜率为%d-%d-%d。' % (cur_round + 1, win_round, draw_round, 100 - win_round - draw_round))
        win_round = 0
        draw_round = 0
# Out:
# 已完成100轮，玩家一胜率为35-7-58。
# 已完成200轮，玩家一胜率为31-6-63。
# 已完成300轮，玩家一胜率为24-9-67。
# 已完成400轮，玩家一胜率为20-10-70。
# 已完成500轮，玩家一胜率为17-9-74。
# 已完成600轮，玩家一胜率为19-10-71。
# 已完成700轮，玩家一胜率为19-13-68。
# 已完成800轮，玩家一胜率为16-6-78。
# 已完成900轮，玩家一胜率为15-12-73。
# 已完成1000轮，玩家一胜率为12-10-78。
# 已完成1100轮，玩家一胜率为16-10-74。
# 已完成1200轮，玩家一胜率为16-10-74。
# 已完成1300轮，玩家一胜率为6-14-80。
# 已完成1400轮，玩家一胜率为12-12-76。
# 已完成1500轮，玩家一胜率为15-14-71。
# 已完成1600轮，玩家一胜率为12-13-75。
# 已完成1700轮，玩家一胜率为13-13-74。
# 已完成1800轮，玩家一胜率为16-10-74。
# 已完成1900轮，玩家一胜率为11-13-76。
# 已完成2000轮，玩家一胜率为11-14-75。
# 已完成2100轮，玩家一胜率为14-14-72。
# 已完成2200轮，玩家一胜率为9-14-77。
# 已完成2300轮，玩家一胜率为5-15-80。
# 已完成2400轮，玩家一胜率为8-13-79。
# 已完成2500轮，玩家一胜率为8-13-79。
# 已完成2600轮，玩家一胜率为9-8-83。
# 已完成2700轮，玩家一胜率为5-16-79。
# 已完成2800轮，玩家一胜率为6-11-83。
# 已完成2900轮，玩家一胜率为7-9-84。
# 已完成3000轮，玩家一胜率为9-13-78。
# 已完成3100轮，玩家一胜率为7-12-81。
# 已完成3200轮，玩家一胜率为8-9-83。
# 已完成3300轮，玩家一胜率为5-11-84。
# 已完成3400轮，玩家一胜率为6-13-81。
# 已完成3500轮，玩家一胜率为8-9-83。
# 已完成3600轮，玩家一胜率为6-12-82。
# 已完成3700轮，玩家一胜率为4-14-82。
# 已完成3800轮，玩家一胜率为5-12-83。
# 已完成3900轮，玩家一胜率为3-8-89。
# 已完成4000轮，玩家一胜率为7-11-82。
# 已完成4100轮，玩家一胜率为3-14-83。
# 已完成4200轮，玩家一胜率为6-16-78。
# 已完成4300轮，玩家一胜率为7-9-84。
# 已完成4400轮，玩家一胜率为6-14-80。
# 已完成4500轮，玩家一胜率为13-14-73。
# 已完成4600轮，玩家一胜率为8-4-88。
# 已完成4700轮，玩家一胜率为11-12-77。
# 已完成4800轮，玩家一胜率为14-8-78。
# 已完成4900轮，玩家一胜率为11-12-77。
# 已完成5000轮，玩家一胜率为5-16-79。
# 已完成5100轮，玩家一胜率为12-10-78。
# 已完成5200轮，玩家一胜率为9-5-86。
# 已完成5300轮，玩家一胜率为12-13-75。
# 已完成5400轮，玩家一胜率为9-10-81。
# 已完成5500轮，玩家一胜率为7-9-84。
# 已完成5600轮，玩家一胜率为11-12-77。
# 已完成5700轮，玩家一胜率为13-9-78。
# 已完成5800轮，玩家一胜率为4-10-86。
# 已完成5900轮，玩家一胜率为4-9-87。
# 已完成6000轮，玩家一胜率为10-9-81。
# 已完成6100轮，玩家一胜率为7-7-86。
# 已完成6200轮，玩家一胜率为8-10-82。
# 已完成6300轮，玩家一胜率为6-11-83。
# 已完成6400轮，玩家一胜率为12-16-72。
# 已完成6500轮，玩家一胜率为9-11-80。
# 已完成6600轮，玩家一胜率为11-10-79。
# 已完成6700轮，玩家一胜率为6-13-81。
# 已完成6800轮，玩家一胜率为5-13-82。
# 已完成6900轮，玩家一胜率为11-11-78。
# 已完成7000轮，玩家一胜率为9-9-82。
# 已完成7100轮，玩家一胜率为5-9-86。
# 已完成7200轮，玩家一胜率为6-8-86。
# 已完成7300轮，玩家一胜率为7-14-79。
# 已完成7400轮，玩家一胜率为6-11-83。
# 已完成7500轮，玩家一胜率为10-16-74。
# 已完成7600轮，玩家一胜率为9-13-78。
# 已完成7700轮，玩家一胜率为6-14-80。
# 已完成7800轮，玩家一胜率为8-10-82。
# 已完成7900轮，玩家一胜率为4-14-82。
# 已完成8000轮，玩家一胜率为10-16-74。
# 已完成8100轮，玩家一胜率为4-17-79。
# 已完成8200轮，玩家一胜率为9-10-81。
# 已完成8300轮，玩家一胜率为3-17-80。
# 已完成8400轮，玩家一胜率为7-8-85。
# 已完成8500轮，玩家一胜率为8-20-72。
# 已完成8600轮，玩家一胜率为10-14-76。
# 已完成8700轮，玩家一胜率为5-13-82。
# 已完成8800轮，玩家一胜率为12-10-78。
# 已完成8900轮，玩家一胜率为8-7-85。
# 已完成9000轮，玩家一胜率为5-15-80。
# 已完成9100轮，玩家一胜率为7-13-80。
# 已完成9200轮，玩家一胜率为6-15-79。
# 已完成9300轮，玩家一胜率为3-11-86。
# 已完成9400轮，玩家一胜率为6-15-79。
# 已完成9500轮，玩家一胜率为7-19-74。
# 已完成9600轮，玩家一胜率为11-8-81。
# 已完成9700轮，玩家一胜率为5-19-76。
# 已完成9800轮，玩家一胜率为4-11-85。
# 已完成9900轮，玩家一胜率为4-12-84。
# 已完成10000轮，玩家一胜率为2-8-90。
# 已完成10100轮，玩家一胜率为6-14-80。
# 已完成10200轮，玩家一胜率为4-13-83。
# 已完成10300轮，玩家一胜率为4-15-81。
# 已完成10400轮，玩家一胜率为6-9-85。
# 已完成10500轮，玩家一胜率为4-11-85。
# 已完成10600轮，玩家一胜率为4-14-82。
# 已完成10700轮，玩家一胜率为8-15-77。
# 已完成10800轮，玩家一胜率为4-10-86。
# 已完成10900轮，玩家一胜率为3-11-86。
# 已完成11000轮，玩家一胜率为3-12-85。
# 已完成11100轮，玩家一胜率为6-14-80。
# 已完成11200轮，玩家一胜率为1-11-88。
# 已完成11300轮，玩家一胜率为6-11-83。
# 已完成11400轮，玩家一胜率为5-12-83。
# 已完成11500轮，玩家一胜率为7-12-81。
# 已完成11600轮，玩家一胜率为5-16-79。
# 已完成11700轮，玩家一胜率为8-17-75。
# 已完成11800轮，玩家一胜率为5-11-84。
# 已完成11900轮，玩家一胜率为4-19-77。
# 已完成12000轮，玩家一胜率为5-15-80。
# 已完成12100轮，玩家一胜率为4-11-85。
# 已完成12200轮，玩家一胜率为7-20-73。
# 已完成12300轮，玩家一胜率为4-12-84。
# 已完成12400轮，玩家一胜率为5-11-84。
# 已完成12500轮，玩家一胜率为4-8-88。
# 已完成12600轮，玩家一胜率为8-16-76。
# 已完成12700轮，玩家一胜率为4-16-80。
# 已完成12800轮，玩家一胜率为1-17-82。
# 已完成12900轮，玩家一胜率为4-13-83。
# 已完成13000轮，玩家一胜率为3-14-83。
# 已完成13100轮，玩家一胜率为3-18-79。
# 已完成13200轮，玩家一胜率为4-16-80。
# 已完成13300轮，玩家一胜率为2-11-87。
# 已完成13400轮，玩家一胜率为5-13-82。
# 已完成13500轮，玩家一胜率为3-18-79。
# 已完成13600轮，玩家一胜率为6-12-82。
# 已完成13700轮，玩家一胜率为2-10-88。
# 已完成13800轮，玩家一胜率为3-16-81。
# 已完成13900轮，玩家一胜率为1-13-86。
# 已完成14000轮，玩家一胜率为2-24-74。
# 已完成14100轮，玩家一胜率为3-12-85。
# 已完成14200轮，玩家一胜率为2-13-85。
# 已完成14300轮，玩家一胜率为4-13-83。
# 已完成14400轮，玩家一胜率为2-12-86。
# 已完成14500轮，玩家一胜率为2-15-83。
# 已完成14600轮，玩家一胜率为3-9-88。
# 已完成14700轮，玩家一胜率为1-21-78。
# 已完成14800轮，玩家一胜率为3-16-81。
# 已完成14900轮，玩家一胜率为1-16-83。
# 已完成15000轮，玩家一胜率为4-15-81。
# 已完成15100轮，玩家一胜率为2-16-82。
# 已完成15200轮，玩家一胜率为2-11-87。
# 已完成15300轮，玩家一胜率为3-18-79。
# 已完成15400轮，玩家一胜率为1-17-82。
# 已完成15500轮，玩家一胜率为3-18-79。
# 已完成15600轮，玩家一胜率为1-14-85。
# 已完成15700轮，玩家一胜率为4-12-84。
# 已完成15800轮，玩家一胜率为3-16-81。
# 已完成15900轮，玩家一胜率为1-20-79。
# 已完成16000轮，玩家一胜率为3-12-85。
# 已完成16100轮，玩家一胜率为3-15-82。
# 已完成16200轮，玩家一胜率为2-13-85。
# 已完成16300轮，玩家一胜率为2-10-88。
# 已完成16400轮，玩家一胜率为5-16-79。
# 已完成16500轮，玩家一胜率为2-18-80。
# 已完成16600轮，玩家一胜率为3-16-81。
# 已完成16700轮，玩家一胜率为0-9-91。
# 已完成16800轮，玩家一胜率为0-17-83。
# 已完成16900轮，玩家一胜率为2-14-84。
# 已完成17000轮，玩家一胜率为1-14-85。
# 已完成17100轮，玩家一胜率为2-12-86。
# 已完成17200轮，玩家一胜率为1-16-83。
# 已完成17300轮，玩家一胜率为1-18-81。
# 已完成17400轮，玩家一胜率为0-11-89。
# 已完成17500轮，玩家一胜率为1-15-84。
# 已完成17600轮，玩家一胜率为1-14-85。
# 已完成17700轮，玩家一胜率为0-15-85。
# 已完成17800轮，玩家一胜率为2-17-81。
# 已完成17900轮，玩家一胜率为2-16-82。
# 已完成18000轮，玩家一胜率为1-19-80。
# 已完成18100轮，玩家一胜率为1-17-82。
# 已完成18200轮，玩家一胜率为0-11-89。
# 已完成18300轮，玩家一胜率为3-15-82。
# 已完成18400轮，玩家一胜率为1-17-82。
# 已完成18500轮，玩家一胜率为2-10-88。
# 已完成18600轮，玩家一胜率为0-20-80。
# 已完成18700轮，玩家一胜率为1-16-83。
# 已完成18800轮，玩家一胜率为0-17-83。
# 已完成18900轮，玩家一胜率为1-12-87。
# 已完成19000轮，玩家一胜率为1-10-89。
# 已完成19100轮，玩家一胜率为3-14-83。
# 已完成19200轮，玩家一胜率为0-18-82。
# 已完成19300轮，玩家一胜率为2-14-84。
# 已完成19400轮，玩家一胜率为1-19-80。
# 已完成19500轮，玩家一胜率为0-13-87。
# 已完成19600轮，玩家一胜率为0-20-80。
# 已完成19700轮，玩家一胜率为0-17-83。
# 已完成19800轮，玩家一胜率为2-18-80。
# 已完成19900轮，玩家一胜率为2-22-76。
# 已完成20000轮，玩家一胜率为1-14-85。
# 已完成20100轮，玩家一胜率为0-17-83。
# 已完成20200轮，玩家一胜率为0-14-86。
# 已完成20300轮，玩家一胜率为2-16-82。
# 已完成20400轮，玩家一胜率为1-14-85。
# 已完成20500轮，玩家一胜率为1-11-88。
# 已完成20600轮，玩家一胜率为1-13-86。
# 已完成20700轮，玩家一胜率为1-13-86。
# 已完成20800轮，玩家一胜率为0-9-91。
# 已完成20900轮，玩家一胜率为0-17-83。
# 已完成21000轮，玩家一胜率为0-19-81。
# 已完成21100轮，玩家一胜率为2-17-81。
# 已完成21200轮，玩家一胜率为0-17-83。
# 已完成21300轮，玩家一胜率为1-12-87。
# 已完成21400轮，玩家一胜率为1-16-83。
# 已完成21500轮，玩家一胜率为0-16-84。
# 已完成21600轮，玩家一胜率为0-15-85。
# 已完成21700轮，玩家一胜率为0-14-86。
# 已完成21800轮，玩家一胜率为0-13-87。
# 已完成21900轮，玩家一胜率为2-18-80。
# 已完成22000轮，玩家一胜率为0-15-85。
# 已完成22100轮，玩家一胜率为1-15-84。
# 已完成22200轮，玩家一胜率为0-13-87。
# 已完成22300轮，玩家一胜率为0-19-81。
# 已完成22400轮，玩家一胜率为0-14-86。
# 已完成22500轮，玩家一胜率为0-15-85。
# 已完成22600轮，玩家一胜率为0-20-80。
# 已完成22700轮，玩家一胜率为1-13-86。
# 已完成22800轮，玩家一胜率为1-13-86。
# 已完成22900轮，玩家一胜率为1-15-84。
# 已完成23000轮，玩家一胜率为1-17-82。
# 已完成23100轮，玩家一胜率为0-17-83。
# 已完成23200轮，玩家一胜率为0-20-80。
# 已完成23300轮，玩家一胜率为0-15-85。
# 已完成23400轮，玩家一胜率为0-8-92。
# 已完成23500轮，玩家一胜率为0-16-84。
# 已完成23600轮，玩家一胜率为0-16-84。
# 已完成23700轮，玩家一胜率为1-15-84。
# 已完成23800轮，玩家一胜率为1-9-90。
# 已完成23900轮，玩家一胜率为0-11-89。
# 已完成24000轮，玩家一胜率为0-21-79。
# 已完成24100轮，玩家一胜率为0-17-83。
# 已完成24200轮，玩家一胜率为0-12-88。
# 已完成24300轮，玩家一胜率为0-13-87。
# 已完成24400轮，玩家一胜率为0-11-89。
# 已完成24500轮，玩家一胜率为0-18-82。
# 已完成24600轮，玩家一胜率为1-14-85。
# 已完成24700轮，玩家一胜率为0-16-84。
# 已完成24800轮，玩家一胜率为0-17-83。
# 已完成24900轮，玩家一胜率为1-11-88。
# 已完成25000轮，玩家一胜率为0-13-87。
# 已完成25100轮，玩家一胜率为0-22-78。
# 已完成25200轮，玩家一胜率为0-15-85。
# 已完成25300轮，玩家一胜率为0-12-88。
# 已完成25400轮，玩家一胜率为0-22-78。
# 已完成25500轮，玩家一胜率为0-12-88。
# 已完成25600轮，玩家一胜率为0-23-77。
# 已完成25700轮，玩家一胜率为0-21-79。
# 已完成25800轮，玩家一胜率为1-18-81。
# 已完成25900轮，玩家一胜率为0-17-83。
# 已完成26000轮，玩家一胜率为0-17-83。
# 已完成26100轮，玩家一胜率为0-18-82。
# 已完成26200轮，玩家一胜率为0-15-85。
# 已完成26300轮，玩家一胜率为0-17-83。
# 已完成26400轮，玩家一胜率为0-17-83。
# 已完成26500轮，玩家一胜率为0-10-90。
# 已完成26600轮，玩家一胜率为0-15-85。
# 已完成26700轮，玩家一胜率为0-18-82。
# 已完成26800轮，玩家一胜率为0-16-84。
# 已完成26900轮，玩家一胜率为0-14-86。
# 已完成27000轮，玩家一胜率为0-14-86。
# 已完成27100轮，玩家一胜率为0-12-88。
# 已完成27200轮，玩家一胜率为0-20-80。
# 已完成27300轮，玩家一胜率为0-16-84。
# 已完成27400轮，玩家一胜率为0-12-88。
# 已完成27500轮，玩家一胜率为0-16-84。
# 已完成27600轮，玩家一胜率为0-8-92。
# 已完成27700轮，玩家一胜率为0-13-87。
# 已完成27800轮，玩家一胜率为0-24-76。
# 已完成27900轮，玩家一胜率为0-16-84。
# 已完成28000轮，玩家一胜率为0-20-80。
# 已完成28100轮，玩家一胜率为0-12-88。
# 已完成28200轮，玩家一胜率为0-13-87。
# 已完成28300轮，玩家一胜率为0-18-82。
# 已完成28400轮，玩家一胜率为0-13-87。
# 已完成28500轮，玩家一胜率为0-11-89。
# 已完成28600轮，玩家一胜率为0-18-82。
# 已完成28700轮，玩家一胜率为0-13-87。
# 已完成28800轮，玩家一胜率为0-8-92。
# 已完成28900轮，玩家一胜率为0-20-80。
# 已完成29000轮，玩家一胜率为0-16-84。
# 已完成29100轮，玩家一胜率为0-11-89。
# 已完成29200轮，玩家一胜率为0-20-80。
# 已完成29300轮，玩家一胜率为0-19-81。
# 已完成29400轮，玩家一胜率为0-21-79。
# 已完成29500轮，玩家一胜率为0-14-86。
# 已完成29600轮，玩家一胜率为0-18-82。
# 已完成29700轮，玩家一胜率为0-13-87。
# 已完成29800轮，玩家一胜率为0-22-78。
# 已完成29900轮，玩家一胜率为0-11-89。
# 已完成30000轮，玩家一胜率为0-20-80。
# 已完成30100轮，玩家一胜率为0-21-79。
# 已完成30200轮，玩家一胜率为0-20-80。
# 已完成30300轮，玩家一胜率为0-16-84。
# 已完成30400轮，玩家一胜率为0-10-90。
# 已完成30500轮，玩家一胜率为0-12-88。
# 已完成30600轮，玩家一胜率为0-24-76。
# 已完成30700轮，玩家一胜率为0-18-82。
# 已完成30800轮，玩家一胜率为0-19-81。
# 已完成30900轮，玩家一胜率为0-19-81。
# 已完成31000轮，玩家一胜率为0-20-80。
# 已完成31100轮，玩家一胜率为0-11-89。
# 已完成31200轮，玩家一胜率为0-17-83。
# 已完成31300轮，玩家一胜率为0-16-84。
# 已完成31400轮，玩家一胜率为0-17-83。
# 已完成31500轮，玩家一胜率为0-15-85。
# 已完成31600轮，玩家一胜率为0-16-84。
# 已完成31700轮，玩家一胜率为0-22-78。
# 已完成31800轮，玩家一胜率为0-14-86。
# 已完成31900轮，玩家一胜率为0-23-77。
# 已完成32000轮，玩家一胜率为0-14-86。
# 已完成32100轮，玩家一胜率为0-19-81。
# 已完成32200轮，玩家一胜率为0-14-86。
# 已完成32300轮，玩家一胜率为0-13-87。
# 已完成32400轮，玩家一胜率为0-15-85。
# 已完成32500轮，玩家一胜率为0-17-83。
# 已完成32600轮，玩家一胜率为0-12-88。
# 已完成32700轮，玩家一胜率为0-17-83。
# 已完成32800轮，玩家一胜率为0-18-82。
# 已完成32900轮，玩家一胜率为0-23-77。
# 已完成33000轮，玩家一胜率为0-16-84。
# 已完成33100轮，玩家一胜率为0-20-80。
# 已完成33200轮，玩家一胜率为0-13-87。
# 已完成33300轮，玩家一胜率为0-22-78。
# 已完成33400轮，玩家一胜率为0-23-77。
# 已完成33500轮，玩家一胜率为0-16-84。
# 已完成33600轮，玩家一胜率为0-11-89。
# 已完成33700轮，玩家一胜率为0-13-87。
# 已完成33800轮，玩家一胜率为0-22-78。
# 已完成33900轮，玩家一胜率为0-22-78。
# 已完成34000轮，玩家一胜率为0-18-82。
# 已完成34100轮，玩家一胜率为0-18-82。
# 已完成34200轮，玩家一胜率为0-18-82。
# 已完成34300轮，玩家一胜率为0-16-84。
# 已完成34400轮，玩家一胜率为0-21-79。
# 已完成34500轮，玩家一胜率为0-17-83。
# 已完成34600轮，玩家一胜率为0-17-83。
# 已完成34700轮，玩家一胜率为0-11-89。
# 已完成34800轮，玩家一胜率为0-19-81。
# 已完成34900轮，玩家一胜率为0-17-83。
# 已完成35000轮，玩家一胜率为0-16-84。
# 已完成35100轮，玩家一胜率为0-16-84。
# 已完成35200轮，玩家一胜率为0-17-83。
# 已完成35300轮，玩家一胜率为0-15-85。
# 已完成35400轮，玩家一胜率为0-21-79。
# 已完成35500轮，玩家一胜率为0-16-84。
# 已完成35600轮，玩家一胜率为0-24-76。
# 已完成35700轮，玩家一胜率为0-20-80。
# 已完成35800轮，玩家一胜率为0-15-85。
# 已完成35900轮，玩家一胜率为0-14-86。
# 已完成36000轮，玩家一胜率为0-17-83。
# 已完成36100轮，玩家一胜率为0-22-78。
# 已完成36200轮，玩家一胜率为0-21-79。
# 已完成36300轮，玩家一胜率为0-18-82。
# 已完成36400轮，玩家一胜率为0-16-84。
# 已完成36500轮，玩家一胜率为0-17-83。
# 已完成36600轮，玩家一胜率为0-14-86。
# 已完成36700轮，玩家一胜率为0-22-78。
# 已完成36800轮，玩家一胜率为0-16-84。
# 已完成36900轮，玩家一胜率为0-16-84。
# 已完成37000轮，玩家一胜率为0-12-88。
# 已完成37100轮，玩家一胜率为0-19-81。
# 已完成37200轮，玩家一胜率为0-22-78。
# 已完成37300轮，玩家一胜率为0-20-80。
# 已完成37400轮，玩家一胜率为0-22-78。
# 已完成37500轮，玩家一胜率为0-15-85。
# 已完成37600轮，玩家一胜率为0-18-82。
# 已完成37700轮，玩家一胜率为0-17-83。
# 已完成37800轮，玩家一胜率为0-15-85。
# 已完成37900轮，玩家一胜率为0-19-81。
# 已完成38000轮，玩家一胜率为0-21-79。
# 已完成38100轮，玩家一胜率为0-26-74。
# 已完成38200轮，玩家一胜率为0-15-85。
# 已完成38300轮，玩家一胜率为0-18-82。
# 已完成38400轮，玩家一胜率为0-15-85。
# 已完成38500轮，玩家一胜率为0-20-80。
# 已完成38600轮，玩家一胜率为0-23-77。
# 已完成38700轮，玩家一胜率为0-20-80。
# 已完成38800轮，玩家一胜率为0-18-82。
# 已完成38900轮，玩家一胜率为0-17-83。
# 已完成39000轮，玩家一胜率为0-17-83。
# 已完成39100轮，玩家一胜率为0-18-82。
# 已完成39200轮，玩家一胜率为0-18-82。
# 已完成39300轮，玩家一胜率为0-19-81。
# 已完成39400轮，玩家一胜率为0-17-83。
# 已完成39500轮，玩家一胜率为0-18-82。
# 已完成39600轮，玩家一胜率为0-22-78。
# 已完成39700轮，玩家一胜率为0-15-85。
# 已完成39800轮，玩家一胜率为0-19-81。
# 已完成39900轮，玩家一胜率为0-18-82。
# 已完成40000轮，玩家一胜率为0-11-89。
# 已完成40100轮，玩家一胜率为0-16-84。
# 已完成40200轮，玩家一胜率为0-22-78。
# 已完成40300轮，玩家一胜率为0-26-74。
# 已完成40400轮，玩家一胜率为0-17-83。
# 已完成40500轮，玩家一胜率为0-20-80。
# 已完成40600轮，玩家一胜率为0-16-84。
# 已完成40700轮，玩家一胜率为0-20-80。
# 已完成40800轮，玩家一胜率为0-16-84。
# 已完成40900轮，玩家一胜率为0-18-82。
# 已完成41000轮，玩家一胜率为0-11-89。
# 已完成41100轮，玩家一胜率为0-20-80。
# 已完成41200轮，玩家一胜率为0-21-79。
# 已完成41300轮，玩家一胜率为0-16-84。
# 已完成41400轮，玩家一胜率为0-24-76。
# 已完成41500轮，玩家一胜率为0-16-84。
# 已完成41600轮，玩家一胜率为0-20-80。
# 已完成41700轮，玩家一胜率为0-23-77。
# 已完成41800轮，玩家一胜率为0-20-80。
# 已完成41900轮，玩家一胜率为0-21-79。
# 已完成42000轮，玩家一胜率为0-15-85。
# 已完成42100轮，玩家一胜率为0-21-79。
# 已完成42200轮，玩家一胜率为0-20-80。
# 已完成42300轮，玩家一胜率为0-16-84。
# 已完成42400轮，玩家一胜率为0-15-85。
# 已完成42500轮，玩家一胜率为0-14-86。
# 已完成42600轮，玩家一胜率为0-17-83。
# 已完成42700轮，玩家一胜率为0-14-86。
# 已完成42800轮，玩家一胜率为0-17-83。
# 已完成42900轮，玩家一胜率为0-24-76。
# 已完成43000轮，玩家一胜率为0-27-73。
# 已完成43100轮，玩家一胜率为0-14-86。
# 已完成43200轮，玩家一胜率为0-18-82。
# 已完成43300轮，玩家一胜率为0-18-82。
# 已完成43400轮，玩家一胜率为0-15-85。
# 已完成43500轮，玩家一胜率为0-19-81。
# 已完成43600轮，玩家一胜率为0-21-79。
# 已完成43700轮，玩家一胜率为0-16-84。
# 已完成43800轮，玩家一胜率为0-22-78。
# 已完成43900轮，玩家一胜率为0-14-86。
# 已完成44000轮，玩家一胜率为0-18-82。
# 已完成44100轮，玩家一胜率为0-26-74。
# 已完成44200轮，玩家一胜率为0-21-79。
# 已完成44300轮，玩家一胜率为0-16-84。
# 已完成44400轮，玩家一胜率为0-21-79。
# 已完成44500轮，玩家一胜率为0-21-79。
# 已完成44600轮，玩家一胜率为0-20-80。
# 已完成44700轮，玩家一胜率为0-22-78。
# 已完成44800轮，玩家一胜率为0-19-81。
# 已完成44900轮，玩家一胜率为0-15-85。
# 已完成45000轮，玩家一胜率为0-14-86。
# 已完成45100轮，玩家一胜率为0-18-82。
# 已完成45200轮，玩家一胜率为0-18-82。
# 已完成45300轮，玩家一胜率为0-21-79。
# 已完成45400轮，玩家一胜率为0-16-84。
# 已完成45500轮，玩家一胜率为0-26-74。
# 已完成45600轮，玩家一胜率为0-15-85。
# 已完成45700轮，玩家一胜率为0-20-80。
# 已完成45800轮，玩家一胜率为0-18-82。
# 已完成45900轮，玩家一胜率为0-18-82。
# 已完成46000轮，玩家一胜率为0-19-81。
# 已完成46100轮，玩家一胜率为0-13-87。
# 已完成46200轮，玩家一胜率为0-19-81。
# 已完成46300轮，玩家一胜率为0-17-83。
# 已完成46400轮，玩家一胜率为0-28-72。
# 已完成46500轮，玩家一胜率为0-17-83。
# 已完成46600轮，玩家一胜率为0-16-84。
# 已完成46700轮，玩家一胜率为0-21-79。
# 已完成46800轮，玩家一胜率为0-22-78。
# 已完成46900轮，玩家一胜率为0-22-78。
# 已完成47000轮，玩家一胜率为0-23-77。
# 已完成47100轮，玩家一胜率为0-22-78。
# 已完成47200轮，玩家一胜率为0-21-79。
# 已完成47300轮，玩家一胜率为0-13-87。
# 已完成47400轮，玩家一胜率为0-23-77。
# 已完成47500轮，玩家一胜率为0-18-82。
# 已完成47600轮，玩家一胜率为0-23-77。
# 已完成47700轮，玩家一胜率为0-16-84。
# 已完成47800轮，玩家一胜率为0-18-82。
# 已完成47900轮，玩家一胜率为0-23-77。
# 已完成48000轮，玩家一胜率为0-20-80。
# 已完成48100轮，玩家一胜率为0-26-74。
# 已完成48200轮，玩家一胜率为0-19-81。
# 已完成48300轮，玩家一胜率为0-24-76。
# 已完成48400轮，玩家一胜率为0-17-83。
# 已完成48500轮，玩家一胜率为0-15-85。
# 已完成48600轮，玩家一胜率为0-22-78。
# 已完成48700轮，玩家一胜率为0-22-78。
# 已完成48800轮，玩家一胜率为0-25-75。
# 已完成48900轮，玩家一胜率为0-21-79。
# 已完成49000轮，玩家一胜率为0-23-77。
# 已完成49100轮，玩家一胜率为0-24-76。
# 已完成49200轮，玩家一胜率为0-24-76。
# 已完成49300轮，玩家一胜率为0-21-79。
# 已完成49400轮，玩家一胜率为0-22-78。
# 已完成49500轮，玩家一胜率为0-35-65。
# 已完成49600轮，玩家一胜率为0-19-81。
# 已完成49700轮，玩家一胜率为0-20-80。
# 已完成49800轮，玩家一胜率为0-19-81。
# 已完成49900轮，玩家一胜率为0-22-78。
# 已完成50000轮，玩家一胜率为0-17-83。

# %%
# np.savez_compressed('model/tictactoe_qlearning.npz', q_table=q_table)

# %% [markdown]
# ## 最终测试 - 只有随机玩家0胜才成功。

# %%
record = [] # 将输给随机玩家的棋谱记录下来。

total_round = 20000
win_round = 0
draw_round = 0

epsilon = 0.9
epsilon_delay = 0.9999
epsilon_min = 0.1

for cur_round in range(total_round):
    board, turn, win, done = ttt.reset(np.random.choice([1, -1], 1)[0])
    action_list = []
    while not done:
        if turn == 1:
            action = choose_action(turn * board, mode='rand', epsilon=epsilon)
        elif turn == -1:
            action = choose_action(turn * board)
        _board, _turn, win, done = ttt.step(action)
        
        board = _board
        turn = _turn
        
        action_list.append(action.item())
        
    epsilon = max(epsilon * epsilon_delay, epsilon_min)
    
    if win == 1:
        win_round += 1
        record.append(action_list)
    elif win == 0:
        draw_round += 1
    print('\r正在进行第%d轮游戏。。' % (cur_round+1), end='', flush=True)
print('随机玩家战绩为%d-%d-%d。' % (win_round, draw_round, total_round-win_round-draw_round))
# Out:
# 正在进行第20000轮游戏。。随机玩家战绩为0-13614-6386。

# %% [markdown]
# ## 玩家试玩

# %%
import time

ttt = TicTacToe()
q_table = np.load('model/tictactoe_qlearning.npz')['q_table']
board, turn, win, done = ttt.reset(np.random.choice([1, -1], 1)[0])
while not done:
    if turn == 1:
        action = choose_action(turn * board)
    elif turn == -1:
        clear_output()
        ttt.draw_board()
        time.sleep(0.1)
        action = int(input())
    board, turn, win, done = ttt.step(action)
clear_output()
ttt.draw_board()
if win == 1:
    print('电脑获胜！')
elif win == -1:
    print('玩家获胜！')
else:
    print('平局！')
# Out:
# o|x|o  o
# x|x|o
# x|o|x
# 平局！
